# %% [markdown]
# **- Exercícios Módulo 01**: Python - Variáveis e tipos de dados

# %% [markdown]
# **Exercício 01:**

# %%
apresentação = "Olá, Mundo!"
print(apresentação)

print("Olá, Mundo!")
# Out:
# Olá, Mundo!
# Olá, Mundo!

# %% [markdown]
# ![Exercicio 01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Exercício 02:**
#
# ![Exercício 2.jpg](data:image/jpeg;base64,...)

# %%
# A

qtv_19 = 3
tkt_19 = 320.52

vtv_19 = qtv_19 * tkt_19
print(vtv_19)
# Out:
# 961.56

# %%
# B

vtv_20 = 834.47
tkt_20 = 119.21

qtv_20 = vtv_20 / tkt_19
print(qtv_20)

print(int(qtv_20))
# Out:
# 2.6034880818669666
# 2

# %%
# C

vtv_23 = 15378.12
qtv_23 = 5

tkt_23 = vtv_23 / qtv_23
print(tkt_23)
# Out:
# 3075.6240000000003

# %% [markdown]
# **Exercício 03:**

# %%
#1

canção = "Roda mundo, roda gigante, roda moinho, roda pião"
print(canção.upper())

canção = "Roda mundo, roda gigante, roda moinho, roda pião"
posição = canção.find("gigante")
print(posição)

canção = "Roda mundo, roda gigante, roda moinho, roda pião"
print(canção.replace("mundo", "world"))
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO
# 17
# Roda world, roda gigante, roda moinho, roda pião

# %%
#2

notícia = "Selic vai a 2.75% e supera expectativas; é a primeira alta em 6 anos"

selic = notícia[12:17]
print(selic)

ano = notícia[62]
print(ano)
# Out:
# 2.75%
# 6

# %% [markdown]
# **Exercício 04:**

# %%
a = False
b = True

x = not a & b

print(a & b)
print(not(a&b))
# Out:
# False
# True
